# %%
import pandas as pd
import os

print("cwd", os.getcwd())
for fn in ["Rj_Risk_Matrisi.csv", "Dij_Mesafe_Matrisi.csv"]:
    df = pd.read_csv(fn)
    print("---", fn, "---")
    print("shape", df.shape)
    print(df.head(10))
    print("unique counts", {col: df[col].nunique() for col in df.columns})
# Out:
# cwd c:\Users\Asus\Downloads\HeliFire-Optimization-main
# --- Rj_Risk_Matrisi.csv ---
# shape (3420, 2)
#    Grid_ID  R_j
# 0        0  0.0
# 1        1  0.0
# 2        2  0.0
# 3        3  0.0
# 4        4  0.0
# 5        5  0.0
# 6        6  0.0
# 7        7  0.0
# 8        8  0.0
# 9        9  0.0
# unique counts {'Grid_ID': 3420, 'R_j': 293}
# --- Dij_Mesafe_Matrisi.csv ---
# shape (629280, 3)
#    Istasyon_ID  Grid_ID     D_ij_km
# 0            0        0  152.798318
# 1            0        1  139.476381
# 2            0        2  126.154399
# 3            0        3  112.832371
# 4            0        4   99.510297
# 5            0        5   86.188178
# 6            0        6   72.866013
# 7            0        7   59.543802
# 8            0        8   46.221546
# 9            0        9   32.899244
# unique counts {'Istasyon_ID': 184, 'Grid_ID': 3420, 'D_ij_km': 383205}
